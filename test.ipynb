# %%
# import libraries

import pandas as pd

# read excel file 
df = pd.read_excel('products.xlsx')

# %%
# see shape 
df.shape
# Out:
# (179154, 38)

# %%
# read csv file 
df3 = pd.read_csv('shopify.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24452\11614197.py:2: DtypeWarning: Columns (4,14,22,23,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('shopify.csv')

# %%
df3.shape
# Out:
# (179154, 56)

# %%
# show all columns 
pd.set_option('display.max_columns', None)

# %%
df.head(2)
# Out:
#               ID                       Handle Command  \
# 0  4513704804492  patrick-mahomes-nike-red-15   MERGE
# 1  4513704804492  patrick-mahomes-nike-red-15   MERGE
#
#                                               Title  Category: ID  \
# 0  NFL Patrick Mahomes Kansas City Chiefs 15 Jersey           NaN
# 1  NFL Patrick Mahomes Kansas City Chiefs 15 Jersey           NaN
#
#   Category: Name Category Custom Collections         Smart Collections  \
# 0            NaN      NaN                nfl  ncaa-1, inkybay-all, all
# 1            NaN      NaN                nfl  ncaa-1, inkybay-all, all
#
#    Variant Inventory Item ID    Variant ID Variant Command  Variant Price  \
# 0               3.610017e+13  3.428143e+13           MERGE          79.99
# 1               3.610017e+13  3.428143e+13           MERGE          79.99
#
#    Variant Compare At Price  Variant Cost  Variant HS Code  \
# 0                       NaN           NaN              NaN
# ...

# %%
df3.head(2)
# Out:
#                            Handle                           Title  \
# 0  rade-krunic-ac-milan-33-jersey  Rade Krunić AC Milan 33 Jersey
# 1  rade-krunic-ac-milan-33-jersey                             NaN
#
#                                          Body (HTML)       Vendor  \
# 0  <style type="text/css" data-mce-fragment="1"><...  JerseyHouse
# 1                                                NaN          NaN
#
#   Product Category     Type  \
# 0              NaN  Jerseys
# 1              NaN      NaN
#
#                                                 Tags Published Option1 Name  \
# 0  AC Milan, club teams, Jerseys, soccer, Zlatan ...      True         Size
# 1                                                NaN       NaN          NaN
#
#   Option1 Value Option2 Name Option2 Value  Option3 Name  Option3 Value  \
# 0       S/Men's        Color         Black           NaN            NaN
# 1       S/Men's          NaN         White           NaN            NaN
#
# ...
